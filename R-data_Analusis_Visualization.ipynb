# %%
library("RColorBrewer")

# %%
data(VADeaths)

# %%
par(mfrow = c(2,3))

# %%
hist(VADeaths,breaks = 10,col=brewer.pal(3,"Set3"),main="Set3 3 colors")
# Out:
# Plot with title “Set3 3 colors”

# %%
hist(VADeaths,breaks = 3,col=brewer.pal(3,"Set2"),main="Set2 3 colors")
# Out:
# Plot with title “Set2 3 colors”

# %%
hist(VADeaths,breaks = 7,col=brewer.pal(3,"Set1"),main="Set3 3 colors")
hist(VADeaths,breaks = 2,col=brewer.pal(8,"Set3"),main="Set3 3 colors")
hist(VADeaths,col=brewer.pal(8,"Greys"),main="Greys 8 colors")
hist(VADeaths,col=brewer.pal(8,"Greys"),main="Green 8 colors")
# Out:
# Plot with title “Set3 3 colors”
# Plot with title “Set3 3 colors”
# Plot with title “Greys 8 colors”
# Plot with title “Green 8 colors”

# %%
## Line Chart
data(AirPassengers)
plot(AirPassengers,type = "l")
# Out:
# plot without title

# %%
## Bar chart 
data("iris")
barplot(iris$Petal.Length)
barplot(iris$Sepal.Length,col=brewer.pal(3,"Set1"))
barplot(table(iris$Species,iris$Sepal.Length),col = brewer.pal(3,"Set1"))
# Out:
# plot without title
# plot without title
# plot without title

# %%
## Box plot 
data(iris)
par(mfrow = c(2,2))
boxplot(iris$Sepal.Length,col='red')
boxplot(iris$Sepal.Length~iris$Species,col = 'red')
boxplot(iris$Sepal.Length~iris$Species,col = heat.colors(3))
boxplot(iris$Sepal.Length~iris$Species,col = topo.colors(3))
boxplot(iris$Sepal.Length~iris$Species)
# Out:
# plot without title
# plot without title

# %%
## Scatter plot 
plot(x=iris$Petal.Length) 
plot(x=iris$Petal.Length,y=iris$Species)
# Out:
# plot without title
# plot without title

# %%
#Heat map
x<-rnorm(10,mean = rep(1:5,each=2),sd = 0.7)
y<-rnorm(10,mean = rep(c(1,9),each=5),sd = 0.1)
dataframe<-data.frame(x=x,y=y)
set.seed(143)
dataMatrix<-as.matrix(dataframe)[sample(1:10),]
heatmap(dataMatrix)
# Out:
# plot without title

# %%
## Correlogram
corr_matrix<-cor(mtcars) 
corrplot(corr_matrix)
corrplot(corr_matrix,method = 'number',type = 'lower')
# Out:
# Error in corrplot(corr_matrix): could not find function "corrplot"
# Traceback:

# %%
## Area plot 
data("airquality")
% > % group_by(Day) % > %
summaries(mean_wind = mean(wind))
% > % ggplot() + geom_area(aes(x=Day,y=mean_wind)) + labs(title='Area chart of average wind per day',subtitle="Using airquality data",y="Mean Wind")%>%d
# Out:
# Error in parse(text = input): <text>:3:1: unexpected SPECIAL
# 2: data("airquality")
# 3: % > %
#    ^
# Traceback:
